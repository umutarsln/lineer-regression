# %%
import pandas as pd

# %%
df = pd.read_csv("../../ahmetqunay/kitap_yurdu_data1.csv")

# %%
df
# Out:
#                                              Unnamed: 0  \
# 0     0,Değişen ve Değişmeyenleri ile COVID-19 D...
# 1                                                     ;
# 2     Dr. Dr. Volkan Öngel",DER YAYINLARI,11/11/2021...
# 3                                                     1
# 4                                                     2
# ...                                                 ...
# 9415                                               8231
# 9416  8232,"Ta'lim'ül Müteallim  İslamda Eğitim Öğre...
# 9417                                               8233
# 9418                                               8234
# 9419                                               8235
#
#                     Book Name Book Genre          Author Name  \
# 0                         NaN        NaN                  NaN
# 1                         NaN        NaN                  NaN
# 2                         NaN        NaN                  NaN
# ...

# %%
df.isnull().sum()
# Out:
# Unnamed: 0               0
# Book Name             1907
# Book Genre            2019
# Author Name           2344
# Publisher             2019
# Publish Date          2191
# Purchase Info         2428
# Page Numbers          2190
# Cover Type            2037
# Paper Type            2037
# Size                  2136
# Language              2036
# Rate                  4357
# Rating Count          4357
# Review Count          5363
# Fav Count             2020
# To-Read List Count    2049
# Price                 2042
# Discount;             2020
# dtype: int64
