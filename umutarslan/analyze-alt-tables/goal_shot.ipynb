# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("../data-v1/goal_shot_creation.csv")

# %%
df.head()
# Out:
#    Unnamed: 0        Squad  # Pl   90s  SCA  SCA90  PassLive  PassDead  TO  \
# 0           1      Arsenal    23  12.0  311  25.92       220        32  20
# 1           2  Aston Villa    23  12.0  315  26.25       234        28  12
# 2           3  Bournemouth    25  12.0  236  19.67       173        15  16
# 3           4    Brentford    25  12.0  294  24.50       200        38  10
# 4           5     Brighton    25  12.0  309  25.75       227        23  23
#
#    Sh  ...  Def  GCA  GCA90  PassLive.1  PassDead.1  TO.1  Sh.1  Fld.1  Def.1  \
# 0  25  ...    5   43   3.58          21           6     3     6      7      0
# 1  28  ...    5   46   3.83          33           1     4     4      3      1
# 2  14  ...    8   15   1.25           9           0     2     2      0      2
# 3  24  ...    6   29   2.42          22           1     1     1      4      0
# 4  20  ...    3   42   3.50          30           1     6     2      2      1
#
#       Season
# 0  2023-2024
# 1  2023-2024
# 2  2023-2024
# 3  2023-2024
# 4  2023-2024
#
# [5 rows x 21 columns]

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Squad', '# Pl', '90s', 'SCA', 'SCA90', 'PassLive',
#        'PassDead', 'TO', 'Sh', 'Fld', 'Def', 'GCA', 'GCA90', 'PassLive.1',
#        'PassDead.1', 'TO.1', 'Sh.1', 'Fld.1', 'Def.1', 'Season'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 140 entries, 0 to 139
# Data columns (total 21 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  140 non-null    int64
#  1   Squad       140 non-null    object
#  2   # Pl        140 non-null    int64
#  3   90s         140 non-null    float64
#  4   SCA         140 non-null    int64
#  5   SCA90       140 non-null    float64
#  6   PassLive    140 non-null    int64
#  7   PassDead    140 non-null    int64
#  8   TO          140 non-null    int64
#  9   Sh          140 non-null    int64
#  10  Fld         140 non-null    int64
#  11  Def         140 non-null    int64
#  12  GCA         140 non-null    int64
#  13  GCA90       140 non-null    float64
#  14  PassLive.1  140 non-null    int64
#  15  PassDead.1  140 non-null    int64
#  16  TO.1        140 non-null    int64
#  17  Sh.1        140 non-null    int64
#  18  Fld.1       140 non-null    int64
#  19  Def.1       140 non-null    int64
#  20  Season      140 non-null    object
# dtypes: float64(3), int64(16), object(2)
# memory usage: 23.1+ KB

# %% [markdown]
# ### Gereksiz sütunları çıkar

# %%
cols = ["Unnamed: 0","# Pl","90s"]
df.drop(columns=cols,axis=1,inplace=True)

# %%
df.head()
# Out:
#          Squad  SCA  SCA90  PassLive  PassDead  TO  Sh  Fld  Def  GCA  GCA90  \
# 0      Arsenal  311  25.92       220        32  20  25    9    5   43   3.58
# 1  Aston Villa  315  26.25       234        28  12  28    8    5   46   3.83
# 2  Bournemouth  236  19.67       173        15  16  14   10    8   15   1.25
# 3    Brentford  294  24.50       200        38  10  24   16    6   29   2.42
# 4     Brighton  309  25.75       227        23  23  20   13    3   42   3.50
#
#    PassLive.1  PassDead.1  TO.1  Sh.1  Fld.1  Def.1     Season
# 0          21           6     3     6      7      0  2023-2024
# 1          33           1     4     4      3      1  2023-2024
# 2           9           0     2     2      0      2  2023-2024
# 3          22           1     1     1      4      0  2023-2024
# 4          30           1     6     2      2      1  2023-2024

# %%
df.corr()
# Out:
#                  SCA     SCA90  PassLive  PassDead        TO        Sh  \
# SCA         1.000000  0.524636  0.990883  0.681258  0.818375  0.862481
# SCA90       0.524636  1.000000  0.579552  0.031348  0.426925  0.465237
# PassLive    0.990883  0.579552  1.000000  0.596176  0.792168  0.826621
# %%
plt.figure(figsize=[20,10])
sns.heatmap(df.corr(), cmap="seismic", annot=True, vmin=-1, vmax=1);

# %%
df.head()
# Out:
#          Squad  SCA  SCA90  PassLive  PassDead  TO  Sh  Fld  Def  GCA  GCA90  \
# 0      Arsenal  311  25.92       220        32  20  25    9    5   43   3.58
# 1  Aston Villa  315  26.25       234        28  12  28    8    5   46   3.83
# 2  Bournemouth  236  19.67       173        15  16  14   10    8   15   1.25
# 3    Brentford  294  24.50       200        38  10  24   16    6   29   2.42
# 4     Brighton  309  25.75       227        23  23  20   13    3   42   3.50
#
#    PassLive.1  PassDead.1  TO.1  Sh.1  Fld.1  Def.1     Season
# 0          21           6     3     6      7      0  2023-2024
# 1          33           1     4     4      3      1  2023-2024
# 2           9           0     2     2      0      2  2023-2024
# 3          22           1     1     1      4      0  2023-2024
# 4          30           1     6     2      2      1  2023-2024

# %%
df.describe().T
# Out:
#             count        mean         std     min       25%      50%      75%  \
# SCA         140.0  752.435714  250.339718  165.00  662.2500  768.000  886.000
# SCA90       140.0   22.072571    4.487576   13.75   18.7475   21.175   25.105
# PassLive    140.0  545.585714  196.127509  122.00  454.7500  538.000  667.750
# PassDead    140.0   64.535714   20.669517   15.00   54.7500   69.000   78.000
# TO          140.0   46.214286   18.970172    4.00   33.7500   46.500   57.000
# Sh          140.0   45.557143   16.441862   10.00   36.0000   45.500   55.250
# Fld         140.0   39.078571   13.572649    7.00   33.0000   42.000   48.250
# Def         140.0   11.464286    4.905452    1.00    8.0000   11.000   15.000
# GCA         140.0   79.785714   36.942067    8.00   57.7500   72.000  104.250
# GCA90       140.0    2.348071    0.906250    0.67    1.6600    2.180    3.000
# PassLive.1  140.0   55.407143   28.647171    5.00   36.0000   47.500   74.000
# PassDead.1  140.0    5.150000    2.682008    0.00    3.0000    5.000    7.000
# TO.1        140.0    5.900000    4.078898    0.00    4.0000    5.000    8.000
# Sh.1        140.0    6.835714    3.607767    0.00    4.0000    7.000    9.000
# Fld.1       140.0    5.314286    2.908894    0.00    3.0000    5.000    7.000
# Def.1       140.0    1.178571    1.218962    0.00    0.0000    1.000    2.000
#
#                 max
# SCA         1356.00
# SCA90         35.68
# PassLive    1040.00
# PassDead     110.00
# TO           101.00
# Sh           104.00
# Fld           60.00
# Def           26.00
# GCA          193.00
# GCA90          5.08
# PassLive.1   150.00
# PassDead.1    12.00
# TO.1          27.00
# Sh.1          19.00
# Fld.1         13.00
# Def.1          6.00

# %% [markdown]
# ## Multicollinearity yüksek olanları çıkar
# ### - Tercihen toplam olan sonuçları çıkar, ortalama olanların kalması daha yararlı

# %%
# per 90 minutes datas'
multicol_cols = ["SCA","GCA","PassLive.1","PassDead.1"]
df.drop(columns=multicol_cols,axis=1,inplace=True)

# %%
df.head()
# Out:
#          Squad  SCA90  PassLive  PassDead  TO  Sh  Fld  Def  GCA90  TO.1  \
# 0      Arsenal  25.92       220        32  20  25    9    5   3.58     3
# 1  Aston Villa  26.25       234        28  12  28    8    5   3.83     4
# 2  Bournemouth  19.67       173        15  16  14   10    8   1.25     2
# 3    Brentford  24.50       200        38  10  24   16    6   2.42     1
# 4     Brighton  25.75       227        23  23  20   13    3   3.50     6
#
#    Sh.1  Fld.1  Def.1     Season
# 0     6      7      0  2023-2024
# 1     4      3      1  2023-2024
# 2     2      0      2  2023-2024
# 3     1      4      0  2023-2024
# 4     2      2      1  2023-2024

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 140 entries, 0 to 139
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Squad     140 non-null    object
#  1   SCA90     140 non-null    float64
#  2   PassLive  140 non-null    int64
#  3   PassDead  140 non-null    int64
#  4   TO        140 non-null    int64
#  5   Sh        140 non-null    int64
#  6   Fld       140 non-null    int64
#  7   Def       140 non-null    int64
#  8   GCA90     140 non-null    float64
#  9   TO.1      140 non-null    int64
#  10  Sh.1      140 non-null    int64
#  11  Fld.1     140 non-null    int64
#  12  Def.1     140 non-null    int64
#  13  Season    140 non-null    object
# dtypes: float64(2), int64(10), object(2)
# memory usage: 15.4+ KB

# %%
df.corr()
# Out:
#              SCA90  PassLive  PassDead        TO        Sh       Fld  \
# SCA90     1.000000  0.579552  0.031348  0.426925  0.465237  0.049725
# PassLive  0.579552  1.000000  0.596176  0.792168  0.826621  0.635416
# PassDead  0.031348  0.596176  1.000000  0.474876  0.713829  0.752534
# TO        0.426925  0.792168  0.474876  1.000000  0.620745  0.587962
# Sh        0.465237  0.826621  0.713829  0.620745  1.000000  0.613552
# Fld       0.049725  0.635416  0.752534  0.587962  0.613552  1.000000
# Def       0.122309  0.481922  0.405869  0.516513  0.507696  0.484936
# GCA90     0.846775  0.488623 -0.018610  0.382022  0.378054  0.050588
# TO.1      0.452904  0.603071  0.241532  0.719170  0.425853  0.392593
# Sh.1      0.326915  0.588990  0.485109  0.475439  0.707172  0.448079
# Fld.1     0.362177  0.600736  0.435831  0.521434  0.488187  0.577732
# Def.1     0.075380  0.193535  0.008168  0.210204  0.145763  0.223089
#
#                Def     GCA90      TO.1      Sh.1     Fld.1     Def.1
# SCA90     0.122309  0.846775  0.452904  0.326915  0.362177  0.075380
# PassLive  0.481922  0.488623  0.603071  0.588990  0.600736  0.193535
# PassDead  0.405869 -0.018610  0.241532  0.485109  0.435831  0.008168
# TO        0.516513  0.382022  0.719170  0.475439  0.521434  0.210204
# Sh        0.507696  0.378054  0.425853  0.707172  0.488187  0.145763
# Fld       0.484936  0.050588  0.392593  0.448079  0.577732  0.223089
# Def       1.000000  0.075470  0.387419  0.371416  0.316908  0.378258
# GCA90     0.075470  1.000000  0.511144  0.396390  0.452351  0.185008
# TO.1      0.387419  0.511144  1.000000  0.373359  0.421041  0.261174
# Sh.1      0.371416  0.396390  0.373359  1.000000  0.318237  0.188304
# Fld.1     0.316908  0.452351  0.421041  0.318237  1.000000  0.213328
# Def.1     0.378258  0.185008  0.261174  0.188304  0.213328  1.000000

# %%
plt.figure(figsize=[20,10])
sns.heatmap(df.corr(), cmap="seismic", annot=True, vmin=-1, vmax=1)
# Out:
# <AxesSubplot:>

# %%
df.isnull().sum()
# Out:
# Squad       0
# SCA90       0
# PassLive    0
# PassDead    0
# TO          0
# Sh          0
# Fld         0
# Def         0
# GCA90       0
# TO.1        0
# Sh.1        0
# Fld.1       0
# Def.1       0
# Season      0
# dtype: int64

# %%
multicol_cols2 = ["TO.1","Sh.1","Fld.1","Def.1"]
df.drop(columns=multicol_cols2,axis=1,inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 140 entries, 0 to 139
# Data columns (total 10 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Squad     140 non-null    object
#  1   SCA90     140 non-null    float64
#  2   PassLive  140 non-null    int64
#  3   PassDead  140 non-null    int64
#  4   TO        140 non-null    int64
#  5   Sh        140 non-null    int64
#  6   Fld       140 non-null    int64
#  7   Def       140 non-null    int64
#  8   GCA90     140 non-null    float64
#  9   Season    140 non-null    object
# dtypes: float64(2), int64(6), object(2)
# memory usage: 11.1+ KB

# %%
plt.figure(figsize=[20,10])
sns.heatmap(df.corr(), cmap="seismic", annot=True, vmin=-1, vmax=1)
# Out:
# <AxesSubplot:>

# %%
df.to_csv("../data-v2/goal_shot.csv", encoding='utf-8')
