# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("../data-v1/passing.csv")

# %%
df.head()
# Out:
#    Unnamed: 0        Squad  # Pl   90s   Cmp   Att  Cmp%  TotDist  PrgDist  \
# 0           1      Arsenal    23  12.0  6268  7341  85.4   107054    32954
# 1           2  Aston Villa    23  12.0  5322  6326  84.1    92330    30547
# 2           3  Bournemouth    25  12.0  3812  4987  76.4    68854    24378
# 3           4    Brentford    25  12.0  4429  5689  77.9    80283    29549
# 4           5     Brighton    25  12.0  6845  7839  87.3   109472    35784
#
#    Cmp.1  ...  Ast   xAG    xA  A-xAG   KP  1/3  PPA  CrsPA  PrgP     Season
# 0   2892  ...   14  12.7  13.3    1.3  131  518  145     21   630  2023-2024
# 1   2346  ...   18  16.7  14.9    1.3  140  440  132     28   496  2023-2024
# 2   1649  ...    6   9.3   8.9   -3.3   96  287   95     19   352  2023-2024
# 3   1916  ...   13  16.7  15.2   -3.7  119  299  104     24   456  2023-2024
# 4   3497  ...   18  16.5  14.8    1.5  137  417  115     21   546  2023-2024
#
# [5 rows x 28 columns]

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Squad', '# Pl', '90s', 'Cmp', 'Att', 'Cmp%', 'TotDist',
#        'PrgDist', 'Cmp.1', 'Att.1', 'Cmp%.1', 'Cmp.2', 'Att.2', 'Cmp%.2',
#        'Cmp.3', 'Att.3', 'Cmp%.3', 'Ast', 'xAG', 'xA', 'A-xAG', 'KP', '1/3',
#        'PPA', 'CrsPA', 'PrgP', 'Season'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 280 entries, 0 to 279
# Data columns (total 28 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  280 non-null    int64
#  1   Squad       280 non-null    object
#  2   # Pl        280 non-null    int64
#  3   90s         280 non-null    float64
#  4   Cmp         280 non-null    int64
#  5   Att         280 non-null    int64
#  6   Cmp%        280 non-null    float64
#  7   TotDist     280 non-null    int64
#  8   PrgDist     280 non-null    int64
#  9   Cmp.1       280 non-null    int64
#  10  Att.1       280 non-null    int64
#  11  Cmp%.1      280 non-null    float64
#  12  Cmp.2       280 non-null    int64
#  13  Att.2       280 non-null    int64
#  14  Cmp%.2      280 non-null    float64
#  15  Cmp.3       280 non-null    int64
#  16  Att.3       280 non-null    int64
#  17  Cmp%.3      280 non-null    float64
#  18  Ast         280 non-null    int64
# ...

# %% [markdown]
# ### Gereksiz sütunları çıkar

# %%
cols = ["Unnamed: 0","# Pl","90s"]
df.drop(columns=cols,axis=1,inplace=True)

# %%
df.head()
# Out:
#          Squad   Cmp   Att  Cmp%  TotDist  PrgDist  Cmp.1  Att.1  Cmp%.1  \
# 0      Arsenal  6268  7341  85.4   107054    32954   2892   3189    90.7
# 1  Aston Villa  5322  6326  84.1    92330    30547   2346   2585    90.8
# 2  Bournemouth  3812  4987  76.4    68854    24378   1649   1880    87.7
# 3    Brentford  4429  5689  77.9    80283    29549   1916   2216    86.5
# 4     Brighton  6845  7839  87.3   109472    35784   3497   3764    92.9
#
#    Cmp.2  ...  Ast   xAG    xA  A-xAG   KP  1/3  PPA  CrsPA  PrgP     Season
# 0   2801  ...   14  12.7  13.3    1.3  131  518  145     21   630  2023-2024
# 1   2441  ...   18  16.7  14.9    1.3  140  440  132     28   496  2023-2024
# 2   1681  ...    6   9.3   8.9   -3.3   96  287   95     19   352  2023-2024
# 3   1967  ...   13  16.7  15.2   -3.7  119  299  104     24   456  2023-2024
# 4   2681  ...   18  16.5  14.8    1.5  137  417  115     21   546  2023-2024
#
# [5 rows x 25 columns]

# %%
df.corr()
# Out:
#               Cmp       Att      Cmp%   TotDist   PrgDist     Cmp.1     Att.1  \
# Cmp      1.000000  0.987308  0.508535  0.992040  0.917660  0.988074  0.988801
# Att      0.987308  1.000000  0.375537  0.991658  0.963758  0.968783  0.980888
# Cmp%     0.508535  0.375537  1.000000  0.445168  0.181265  0.530264  0.474807
# TotDist  0.992040  0.991658  0.445168  1.000000  0.948599  0.963546  0.969840
# PrgDist  0.917660  0.963758  0.181265  0.948599  1.000000  0.879235  0.906403
# Cmp.1    0.988074  0.968783  0.530264  0.963546  0.879235  1.000000  0.997234
# Att.1    0.988801  0.980888  0.474807  0.969840  0.906403  0.997234  1.000000
# Cmp%.1   0.454131  0.320258  0.966341  0.382672  0.117449  0.491769  0.431392
# Cmp.2    0.983903  0.963219  0.550949  0.984610  0.894509  0.952680  0.950594
# Att.2    0.984633  0.980093  0.470082  0.992987  0.932375  0.949634  0.954873
# Cmp%.2   0.447915  0.314146  0.975337  0.391236  0.125588  0.456112  0.400367
# ...

# %%
plt.figure(figsize=[20,10])
sns.heatmap(df.corr(), cmap="seismic", annot=True, vmin=-1, vmax=1);

# %%
df.head()
# Out:
#          Squad   Cmp   Att  Cmp%  TotDist  PrgDist  Cmp.1  Att.1  Cmp%.1  \
# 0      Arsenal  6268  7341  85.4   107054    32954   2892   3189    90.7
# 1  Aston Villa  5322  6326  84.1    92330    30547   2346   2585    90.8
# 2  Bournemouth  3812  4987  76.4    68854    24378   1649   1880    87.7
# 3    Brentford  4429  5689  77.9    80283    29549   1916   2216    86.5
# 4     Brighton  6845  7839  87.3   109472    35784   3497   3764    92.9
#
#    Cmp.2  ...  Ast   xAG    xA  A-xAG   KP  1/3  PPA  CrsPA  PrgP     Season
# 0   2801  ...   14  12.7  13.3    1.3  131  518  145     21   630  2023-2024
# 1   2441  ...   18  16.7  14.9    1.3  140  440  132     28   496  2023-2024
# 2   1681  ...    6   9.3   8.9   -3.3   96  287   95     19   352  2023-2024
# 3   1967  ...   13  16.7  15.2   -3.7  119  299  104     24   456  2023-2024
# 4   2681  ...   18  16.5  14.8    1.5  137  417  115     21   546  2023-2024
#
# [5 rows x 25 columns]

# %%
df.describe().T
# Out:
#          count           mean           std      min         25%        50%  \
# Cmp      280.0   13530.042857   5088.733809   2841.0   10835.500   13134.00
# Att      280.0   17265.778571   5777.972873   4172.0   15370.750   17452.50
# Cmp%     280.0      77.701429      5.279024     61.2      73.575      77.75
# TotDist  280.0  235845.535714  83748.866268  54127.0  197268.250  236636.50
# PrgDist  280.0   84667.400000  25437.453398  23665.0   80083.000   89247.00
# Cmp.1    280.0    6281.035714   2465.508012   1266.0    4946.750    6025.50
# Att.1    280.0    7160.035714   2646.457860   1524.0    5875.500    6990.00
# Cmp%.1   280.0      87.241429      3.036032     76.7      84.900      87.35
# Cmp.2    280.0    5420.064286   2147.995092   1081.0    4120.250    5195.00
# Att.2    280.0    6412.928571   2338.321509   1398.0    5129.750    6202.50
# Cmp%.2   280.0      83.843571      4.360810     70.1      80.300      84.50
# ...

# %% [markdown]
# ## Multicollinearity yüksek olanları çıkar
# ### - Tercihen toplam olan sonuçları çıkar, ortalama olanların kalması daha yararlı

# %%
multicol_cols = ["Cmp","Att","Cmp.1","Att.1","Cmp.2","Att.2","Cmp.3","Att.3","xAG","xA","A-xAG"]
df.drop(columns=multicol_cols,axis=1,inplace=True)

# %%
df.head()
# Out:
#          Squad  Cmp%  TotDist  PrgDist  Cmp%.1  Cmp%.2  Cmp%.3  Ast   KP  1/3  \
# 0      Arsenal  85.4   107054    32954    90.7    90.6    59.6   14  131  518
# 1  Aston Villa  84.1    92330    30547    90.8    89.3    58.4   18  140  440
# 2  Bournemouth  76.4    68854    24378    87.7    85.7    45.2    6   96  287
# 3    Brentford  77.9    80283    29549    86.5    84.2    52.9   13  119  299
# 4     Brighton  87.3   109472    35784    92.9    90.5    62.9   18  137  417
#
#    PPA  CrsPA  PrgP     Season
# 0  145     21   630  2023-2024
# 1  132     28   496  2023-2024
# 2   95     19   352  2023-2024
# 3  104     24   456  2023-2024
# 4  115     21   546  2023-2024

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 280 entries, 0 to 279
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Squad    280 non-null    object
#  1   Cmp%     280 non-null    float64
#  2   TotDist  280 non-null    int64
#  3   PrgDist  280 non-null    int64
#  4   Cmp%.1   280 non-null    float64
#  5   Cmp%.2   280 non-null    float64
#  6   Cmp%.3   280 non-null    float64
#  7   Ast      280 non-null    int64
#  8   KP       280 non-null    int64
#  9   1/3      280 non-null    int64
#  10  PPA      280 non-null    int64
#  11  CrsPA    280 non-null    int64
#  12  PrgP     280 non-null    int64
#  13  Season   280 non-null    object
# dtypes: float64(4), int64(8), object(2)
# memory usage: 30.8+ KB

# %%
df.corr()
# Out:
#              Cmp%   TotDist   PrgDist    Cmp%.1    Cmp%.2    Cmp%.3       Ast  \
# Cmp%     1.000000  0.445168  0.181265  0.966341  0.975337  0.889740  0.466334
# TotDist  0.445168  1.000000  0.948599  0.382672  0.391236  0.546688  0.845233
# PrgDist  0.181265  0.948599  1.000000  0.117449  0.125588  0.320396  0.775834
# Cmp%.1   0.966341  0.382672  0.117449  1.000000  0.937273  0.816805  0.410247
# Cmp%.2   0.975337  0.391236  0.125588  0.937273  1.000000  0.826473  0.393789
# Cmp%.3   0.889740  0.546688  0.320396  0.816805  0.826473  1.000000  0.555050
# Ast      0.466334  0.845233  0.775834  0.410247  0.393789  0.555050  1.000000
# KP       0.315944  0.934008  0.925834  0.255470  0.253375  0.429646  0.852001
# 1/3      0.419008  0.968544  0.922460  0.360995  0.347888  0.526797  0.868002
# PPA      0.442142  0.928204  0.870565  0.388004  0.377781  0.530550  0.884709
# CrsPA   -0.243387  0.557552  0.693641 -0.268347 -0.272458 -0.045777  0.416068
# ...

# %%
plt.figure(figsize=[20,10])
sns.heatmap(df.corr(), cmap="seismic", annot=True, vmin=-1, vmax=1)
# Out:
# <AxesSubplot:>

# %%
df.isnull().sum()
# Out:
# Squad      0
# Cmp%       0
# TotDist    0
# PrgDist    0
# Cmp%.1     0
# Cmp%.2     0
# Cmp%.3     0
# Ast        0
# KP         0
# 1/3        0
# PPA        0
# CrsPA      0
# PrgP       0
# Season     0
# dtype: int64

# %%
multicol_cols2 = ["Cmp%.1","Cmp%.2","Cmp%.3","TotDist","PrgDist","PrgP","PPA"]
df.drop(columns=multicol_cols2,axis=1,inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 280 entries, 0 to 279
# Data columns (total 7 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Squad   280 non-null    object
#  1   Cmp%    280 non-null    float64
#  2   Ast     280 non-null    int64
#  3   KP      280 non-null    int64
#  4   1/3     280 non-null    int64
#  5   CrsPA   280 non-null    int64
#  6   Season  280 non-null    object
# dtypes: float64(1), int64(4), object(2)
# memory usage: 15.4+ KB

# %%
plt.figure(figsize=[20,10])
sns.heatmap(df.corr(), cmap="seismic", annot=True, vmin=-1, vmax=1)
# Out:
# <AxesSubplot:>

# %%
df = df.iloc[0:140]

# %%
df
# Out:
#             Squad  Cmp%  Ast   KP   1/3  CrsPA     Season
# 0         Arsenal  85.4   14  131   518     21  2023-2024
# 1     Aston Villa  84.1   18  140   440     28  2023-2024
# 2     Bournemouth  76.4    6   96   287     19  2023-2024
# 3       Brentford  77.9   13  119   299     24  2023-2024
# 4        Brighton  87.3   18  137   417     21  2023-2024
# ..            ...   ...  ...  ...   ...    ...        ...
# 135  Swansea City  75.8   20  223   973     57  2017-2018
# 136     Tottenham  81.4   51  462  1793     63  2017-2018
# 137       Watford  72.8   27  320  1071     79  2017-2018
# 138     West Brom  69.9   24  272   967    115  2017-2018
# 139      West Ham  72.7   29  278   989     78  2017-2018
#
# [140 rows x 7 columns]

# %%
df.to_csv("../data-v2/passing.csv", encoding='utf-8')
