# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("../data-v1/standart_stats.csv")

# %%
df.head()
# Out:
#    Unnamed: 0        Squad  npxG  npxG.1  npxG+xAG  npxG+xAG.1   xAG  xAG.1  \
# 0           1      Arsenal  16.5    1.38      29.3        2.44  12.7   1.06
# 1           2  Aston Villa  21.2    1.77      37.9        3.16  16.7   1.39
# 2           3  Bournemouth  13.8    1.15      23.1        1.93   9.3   0.77
# 3           4    Brentford  20.8    1.73      37.5        3.12  16.7   1.39
# 4           5     Brighton  20.0    1.67      36.5        3.04  16.5   1.38
#
#      xG  xG.1  ...   90s  MP   Min  Starts   PrgC   PrgP  # Pl   Age  Poss  \
# 0  21.0  1.75  ...  12.0  12  1080     132  245.0  630.0    23  25.2  60.7
# 1  23.5  1.96  ...  12.0  12  1080     132  254.0  496.0    23  27.1  53.8
# 2  13.8  1.15  ...  12.0  12  1080     132  197.0  352.0    25  25.7  42.9
# 3  22.1  1.84  ...  12.0  12  1080     132  172.0  456.0    25  26.6  47.7
# 4  20.8  1.73  ...  12.0  12  1080     132  284.0  546.0    25  27.2  61.4
#
#       Season
# 0  2023-2024
# 1  2023-2024
# 2  2023-2024
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Squad', 'npxG', 'npxG.1', 'npxG+xAG', 'npxG+xAG.1',
#        'xAG', 'xAG.1', 'xG', 'xG.1', 'Ast', 'Ast.1', 'G+A', 'G+A.1', 'G+A-PK',
#        'G-PK', 'G-PK.1', 'Gls', 'Gls.1', 'xG+xAG', 'CrdR', 'CrdY', 'PK',
#        'PKatt', '90s', 'MP', 'Min', 'Starts', 'PrgC', 'PrgP', '# Pl', 'Age',
#        'Poss', 'Season'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 646 entries, 0 to 645
# Data columns (total 34 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  646 non-null    int64
#  1   Squad       646 non-null    object
#  2   npxG        140 non-null    float64
#  3   npxG.1      140 non-null    float64
#  4   npxG+xAG    140 non-null    float64
#  5   npxG+xAG.1  140 non-null    float64
#  6   xAG         140 non-null    float64
#  7   xAG.1       140 non-null    float64
#  8   xG          140 non-null    float64
#  9   xG.1        140 non-null    float64
#  10  Ast         646 non-null    float64
#  11  Ast.1       646 non-null    int64
#  12  G+A         646 non-null    float64
#  13  G+A.1       646 non-null    int64
#  14  G+A-PK      646 non-null    float64
#  15  G-PK        646 non-null    float64
#  16  G-PK.1      646 non-null    int64
#  17  Gls         646 non-null    float64
#  18  Gls.1       646 non-null    int64
# ...

# %% [markdown]
# ### Gereksiz sütunları çıkar

# %%
cols = ["Unnamed: 0","# Pl","90s","MP","Min","Starts","PKatt","PK","CrdY","CrdR","Age"]
df.drop(columns=cols,axis=1,inplace=True)

# %%
df.head()
# Out:
#          Squad  npxG  npxG.1  npxG+xAG  npxG+xAG.1   xAG  xAG.1    xG  xG.1  \
# 0      Arsenal  16.5    1.38      29.3        2.44  12.7   1.06  21.0  1.75
# 1  Aston Villa  21.2    1.77      37.9        3.16  16.7   1.39  23.5  1.96
# 2  Bournemouth  13.8    1.15      23.1        1.93   9.3   0.77  13.8  1.15
# 3    Brentford  20.8    1.73      37.5        3.12  16.7   1.39  22.1  1.84
# 4     Brighton  20.0    1.67      36.5        3.04  16.5   1.38  20.8  1.73
#
#     Ast  ...  G+A-PK  G-PK  G-PK.1   Gls  Gls.1  xG+xAG   PrgC   PrgP  Poss  \
# 0  1.17  ...    2.75  1.58      19  2.08     25    2.81  245.0  630.0  60.7
# 1  1.50  ...    3.42  1.92      23  2.17     26    3.35  254.0  496.0  53.8
# 2  0.50  ...    1.42  0.92      11  0.92     11    1.93  197.0  352.0  42.9
# 3  1.08  ...    2.42  1.33      16  1.50     18    3.23  172.0  456.0  47.7
# 4  1.50  ...    3.33  1.83      22  1.92     23    3.11  284.0  546.0  61.4
#
#       Season
# 0  2023-2024
# 1  2023-2024
# ...

# %%
df.corr()
# Out:
#                 npxG    npxG.1  npxG+xAG  npxG+xAG.1       xAG     xAG.1  \
# npxG        1.000000  0.589779  0.998148    0.584289  0.990565  0.570712
# npxG.1      0.589779  1.000000  0.599541    0.996410  0.608546  0.982584
# npxG+xAG    0.998148  0.599541  1.000000    0.598680  0.997064  0.590516
# npxG+xAG.1  0.584289  0.996410  0.598680    1.000000  0.613517  0.994719
# xAG         0.990565  0.608546  0.997064    0.613517  1.000000  0.612211
# xAG.1       0.570712  0.982584  0.590516    0.994719  0.612211  1.000000
# xG          0.993310  0.580756  0.991339    0.575340  0.983566  0.561738
# xG.1        0.576298  0.984686  0.585706    0.980961  0.594222  0.966688
# Ast         0.567743  0.869847  0.583854    0.880785  0.600857  0.885978
# Ast.1       0.915234  0.628113  0.921745    0.632019  0.924997  0.629683
# G+A         0.577812  0.897275  0.589931    0.901267  0.601796  0.897613
# G+A.1       0.934546  0.628152  0.937157    0.627034  0.935370  0.618611
# ...

# %%
plt.figure(figsize=[20,10])
sns.heatmap(df.corr(), cmap="seismic", annot=True, vmin=-1, vmax=1);

# %%
df.head()
# Out:
#          Squad  npxG  npxG.1  npxG+xAG  npxG+xAG.1   xAG  xAG.1    xG  xG.1  \
# 0      Arsenal  16.5    1.38      29.3        2.44  12.7   1.06  21.0  1.75
# 1  Aston Villa  21.2    1.77      37.9        3.16  16.7   1.39  23.5  1.96
# 2  Bournemouth  13.8    1.15      23.1        1.93   9.3   0.77  13.8  1.15
# 3    Brentford  20.8    1.73      37.5        3.12  16.7   1.39  22.1  1.84
# 4     Brighton  20.0    1.67      36.5        3.04  16.5   1.38  20.8  1.73
#
#     Ast  ...  G+A-PK  G-PK  G-PK.1   Gls  Gls.1  xG+xAG   PrgC   PrgP  Poss  \
# 0  1.17  ...    2.75  1.58      19  2.08     25    2.81  245.0  630.0  60.7
# 1  1.50  ...    3.42  1.92      23  2.17     26    3.35  254.0  496.0  53.8
# 2  0.50  ...    1.42  0.92      11  0.92     11    1.93  197.0  352.0  42.9
# 3  1.08  ...    2.42  1.33      16  1.50     18    3.23  172.0  456.0  47.7
# 4  1.50  ...    3.33  1.83      22  1.92     23    3.11  284.0  546.0  61.4
#
#       Season
# 0  2023-2024
# 1  2023-2024
# ...

# %%
df.describe().T
# Out:
#             count         mean         std     min        25%       50%  \
# npxG        140.0    42.557857   15.761510    8.10    34.4000    42.100
# npxG.1      140.0     1.256286    0.337126    0.67     1.0000     1.190
# npxG+xAG    140.0    75.385000   28.288030   12.90    60.7250    74.100
# npxG+xAG.1  140.0     2.226214    0.616750    1.08     1.7600     2.080
# xAG         140.0    32.826429   12.594807    4.80    25.8750    32.200
# xAG.1       140.0     0.969786    0.281730    0.40     0.7575     0.900
# xG          140.0    46.077857   17.007485    9.70    36.7750    46.000
# xG.1        140.0     1.359857    0.368235    0.76     1.0700     1.285
# Ast         646.0     0.911486    0.318532    0.25     0.6800     0.840
# Ast.1       646.0    34.165635   12.419619    3.00    26.0000    32.000
# G+A         646.0     2.206827    0.698248    0.82     1.7400     2.050
# G+A.1       646.0    82.721362   27.511121   10.00    65.0000    78.000
# ...

# %% [markdown]
# ## Multicollinearity yüksek olanları çıkar
# ### - Tercihen toplam olan sonuçları çıkar, ortalama olanların kalması daha yararlı

# %%
# per 90 minutes datas'
multicol_cols = ["npxG","npxG+xAG","xAG","xG","Ast.1","G+A.1","G-PK.1","Gls.1"]
df.drop(columns=multicol_cols,axis=1,inplace=True)

# %%
df.head()
# Out:
#          Squad  npxG.1  npxG+xAG.1  xAG.1  xG.1   Ast   G+A  G+A-PK  G-PK  \
# 0      Arsenal    1.38        2.44   1.06  1.75  1.17  3.25    2.75  1.58
# 1  Aston Villa    1.77        3.16   1.39  1.96  1.50  3.67    3.42  1.92
# 2  Bournemouth    1.15        1.93   0.77  1.15  0.50  1.42    1.42  0.92
# 3    Brentford    1.73        3.12   1.39  1.84  1.08  2.58    2.42  1.33
# 4     Brighton    1.67        3.04   1.38  1.73  1.50  3.42    3.33  1.83
#
#     Gls  xG+xAG   PrgC   PrgP  Poss     Season
# 0  2.08    2.81  245.0  630.0  60.7  2023-2024
# 1  2.17    3.35  254.0  496.0  53.8  2023-2024
# 2  0.92    1.93  197.0  352.0  42.9  2023-2024
# 3  1.50    3.23  172.0  456.0  47.7  2023-2024
# 4  1.92    3.11  284.0  546.0  61.4  2023-2024

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 646 entries, 0 to 645
# Data columns (total 15 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Squad       646 non-null    object
#  1   npxG.1      140 non-null    float64
#  2   npxG+xAG.1  140 non-null    float64
#  3   xAG.1       140 non-null    float64
#  4   xG.1        140 non-null    float64
#  5   Ast         646 non-null    float64
#  6   G+A         646 non-null    float64
#  7   G+A-PK      646 non-null    float64
#  8   G-PK        646 non-null    float64
#  9   Gls         646 non-null    float64
#  10  xG+xAG      140 non-null    float64
#  11  PrgC        140 non-null    float64
#  12  PrgP        140 non-null    float64
#  13  Poss        200 non-null    float64
#  14  Season      646 non-null    object
# dtypes: float64(13), object(2)
# memory usage: 75.8+ KB

# %%
df.corr()
# Out:
#               npxG.1  npxG+xAG.1     xAG.1      xG.1       Ast       G+A  \
# npxG.1      1.000000    0.996410  0.982584  0.984686  0.869847  0.897275
# npxG+xAG.1  0.996410    1.000000  0.994719  0.980961  0.880785  0.901267
# xAG.1       0.982584    0.994719  1.000000  0.966688  0.885978  0.897613
# xG.1        0.984686    0.980961  0.966688  1.000000  0.864329  0.905348
# Ast         0.869847    0.880785  0.885978  0.864329  1.000000  0.980034
# G+A         0.897275    0.901267  0.897613  0.905348  0.980034  1.000000
# G+A-PK      0.895433    0.900040  0.897217  0.890678  0.983082  0.996825
# G-PK        0.904584    0.903773  0.894228  0.900426  0.942068  0.984302
# Gls         0.902915    0.901391  0.890879  0.921427  0.934919  0.986769
# xG+xAG      0.991849    0.995073  0.989237  0.993683  0.880812  0.909401
# PrgC        0.414561    0.414965  0.409937  0.416818  0.470486  0.474314
# PrgP        0.450499    0.451006  0.445350  0.449105  0.486549  0.491579
# ...

# %%
plt.figure(figsize=[20,10])
sns.heatmap(df.corr(), cmap="seismic", annot=True, vmin=-1, vmax=1)
# Out:
# <AxesSubplot:>

# %%
df.isnull().sum()
# Out:
# Squad           0
# npxG.1        506
# npxG+xAG.1    506
# xAG.1         506
# xG.1          506
# Ast             0
# G+A             0
# G+A-PK          0
# G-PK            0
# Gls             0
# xG+xAG        506
# PrgC          506
# PrgP          506
# Poss          446
# Season          0
# dtype: int64

# %%
multicol_cols2 = ["npxG.1","npxG+xAG.1","xAG.1","xG.1","xG+xAG","PrgC","G+A","G+A-PK","G-PK"]
df.drop(columns=multicol_cols2,axis=1,inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 646 entries, 0 to 645
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Squad   646 non-null    object
#  1   Ast     646 non-null    float64
#  2   Gls     646 non-null    float64
#  3   PrgP    140 non-null    float64
#  4   Poss    200 non-null    float64
#  5   Season  646 non-null    object
# dtypes: float64(4), object(2)
# memory usage: 30.4+ KB

# %%
plt.figure(figsize=[20,10])
sns.heatmap(df.corr(), cmap="seismic", annot=True, vmin=-1, vmax=1)
# Out:
# <AxesSubplot:>

# %%
df = df.iloc[0:140]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 140 entries, 0 to 139
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Squad   140 non-null    object
#  1   Ast     140 non-null    float64
#  2   Gls     140 non-null    float64
#  3   PrgP    140 non-null    float64
#  4   Poss    140 non-null    float64
#  5   Season  140 non-null    object
# dtypes: float64(4), object(2)
# memory usage: 6.7+ KB

# %%
df.to_csv("../data-v2/standart_stats.csv", encoding='utf-8')
