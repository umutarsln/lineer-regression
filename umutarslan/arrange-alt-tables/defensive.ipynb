# %%
import pandas as pd
import numpy as np

# %%
df_defensive = pd.read_csv("../data/defensive_action.csv")

# %%
df_defensive.head()
# Out:
#    Unnamed: 0 Unnamed: 0_level_0 Unnamed: 1_level_0 Unnamed: 2_level_0  \
# 0         NaN              Squad               # Pl                90s
# 1         0.0            Arsenal                 23               12.0
# 2         1.0        Aston Villa                 23               12.0
# 3         2.0        Bournemouth                 25               12.0
# 4         3.0          Brentford                 25               12.0
#
#   Tackles Tackles.1 Tackles.2 Tackles.3 Tackles.4 Challenges  ...  \
# 0     Tkl      TklW   Def 3rd   Mid 3rd   Att 3rd        Tkl  ...
# 1     196       109        79        84        33         98  ...
# 2     173       100        83        74        16         78  ...
# 3     224       122       104        89        31        105  ...
# 4     196       123       104        74        18         87  ...
#
#   Challenges.2 Challenges.3  Blocks Blocks.1 Blocks.2 Unnamed: 15_level_0  \
# ...

# %%
df_defensive.drop('Unnamed: 0', axis=1, inplace=True)

# %%
df_defensive.head()
# Out:
#   Unnamed: 0_level_0 Unnamed: 1_level_0 Unnamed: 2_level_0 Tackles Tackles.1  \
# 0              Squad               # Pl                90s     Tkl      TklW
# 1            Arsenal                 23               12.0     196       109
# 2        Aston Villa                 23               12.0     173       100
# 3        Bournemouth                 25               12.0     224       122
# 4          Brentford                 25               12.0     196       123
#
#   Tackles.2 Tackles.3 Tackles.4 Challenges Challenges.1 Challenges.2  \
# 0   Def 3rd   Mid 3rd   Att 3rd        Tkl          Att         Tkl%
# 1        79        84        33         98          168         58.3
# 2        83        74        16         78          179         43.6
# 3       104        89        31        105          222         47.3
# 4       104        74        18         87          201         43.3
#
#   Challenges.3  Blocks Blocks.1 Blocks.2 Unnamed: 15_level_0  \
# ...

# %%
cols = list(df_defensive.iloc[0])
cols[-1] = "Season"
cols
# Out:
# ['Squad',
#  '# Pl',
#  '90s',
#  'Tkl',
#  'TklW',
#  'Def 3rd',
#  'Mid 3rd',
#  'Att 3rd',
#  'Tkl',
#  'Att',
#  'Tkl%',
#  'Lost',
#  'Blocks',
#  'Sh',
#  'Pass',
#  'Int',
#  'Tkl+Int',
#  'Clr',
#  'Err',
#  'Season']

# %%
df_defensive.columns = cols

# %%
df_defensive.columns
# Out:
# Index(['Squad', '# Pl', '90s', 'Tkl', 'TklW', 'Def 3rd', 'Mid 3rd', 'Att 3rd',
#        'Tkl', 'Att', 'Tkl%', 'Lost', 'Blocks', 'Sh', 'Pass', 'Int', 'Tkl+Int',
#        'Clr', 'Err', 'Season'],
#       dtype='object')

# %%
df_defensive.head()
# Out:
#          Squad  # Pl   90s  Tkl  TklW  Def 3rd  Mid 3rd  Att 3rd  Tkl  Att  \
# 0        Squad  # Pl   90s  Tkl  TklW  Def 3rd  Mid 3rd  Att 3rd  Tkl  Att
# 1      Arsenal    23  12.0  196   109       79       84       33   98  168
# 2  Aston Villa    23  12.0  173   100       83       74       16   78  179
# 3  Bournemouth    25  12.0  224   122      104       89       31  105  222
# 4    Brentford    25  12.0  196   123      104       74       18   87  201
#
#    Tkl%  Lost  Blocks  Sh  Pass  Int  Tkl+Int  Clr  Err     Season
# 0  Tkl%  Lost  Blocks  Sh  Pass  Int  Tkl+Int  Clr  Err        NaN
# 1  58.3    70     152  38   114   91      287  130    6  2023-2024
# 2  43.6   101     120  32    88   81      254  171    3  2023-2024
# 3  47.3   117     150  49   101  104      328  230    8  2023-2024
# 4  43.3   114     137  32   105  102      298  290    4  2023-2024

# %%
df_defensive.drop(0,inplace=True)

# %%
df_defensive
# Out:
#             Squad # Pl   90s  Tkl TklW Def 3rd Mid 3rd Att 3rd  Tkl  Att  \
# 1         Arsenal   23  12.0  196  109      79      84      33   98  168
# 2     Aston Villa   23  12.0  173  100      83      74      16   78  179
# 3     Bournemouth   25  12.0  224  122     104      89      31  105  222
# 4       Brentford   25  12.0  196  123     104      74      18   87  201
# 5        Brighton   25  12.0  187  114      89      76      22   78  209
# ..            ...  ...   ...  ...  ...     ...     ...     ...  ...  ...
# 136  Swansea City   26  38.0  610  417     286     241      83  221  550
# 137     Tottenham   25  38.0  618  399     272     259      87  212  537
# 138       Watford   29  38.0  668  432     337     263      68  237  609
# 139     West Brom   24  38.0  603  385     336     204      63  218  625
# 140      West Ham   27  38.0  621  410     327     238      56  235  620
#
#      Tkl% Lost Blocks   Sh Pass  Int Tkl+Int   Clr Err     Season
# ...

# %%
df_defensive.to_csv("../data-v1/defensive_action.csv", encoding='utf-8')
