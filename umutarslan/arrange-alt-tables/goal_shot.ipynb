# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("../data/goal_shot_creation.csv")

# %%
df.head()
# Out:
#    Unnamed: 0 Unnamed: 0_level_0 Unnamed: 1_level_0 Unnamed: 2_level_0  SCA  \
# 0         NaN              Squad               # Pl                90s  SCA
# 1         0.0            Arsenal                 23               12.0  311
# 2         1.0        Aston Villa                 23               12.0  315
# 3         2.0        Bournemouth                 25               12.0  236
# 4         3.0          Brentford                 25               12.0  294
#
#    SCA.1 SCA Types SCA Types.1 SCA Types.2 SCA Types.3  ... SCA Types.5  GCA  \
# 0  SCA90  PassLive    PassDead          TO          Sh  ...         Def  GCA
# 1  25.92       220          32          20          25  ...           5   43
# 2  26.25       234          28          12          28  ...           5   46
# 3  19.67       173          15          16          14  ...           8   15
# 4   24.5       200          38          10          24  ...           6   29
#
# ...

# %%
df.drop('Unnamed: 0', axis=1, inplace=True)

# %%
df.head()
# Out:
#   Unnamed: 0_level_0 Unnamed: 1_level_0 Unnamed: 2_level_0  SCA  SCA.1  \
# 0              Squad               # Pl                90s  SCA  SCA90
# 1            Arsenal                 23               12.0  311  25.92
# 2        Aston Villa                 23               12.0  315  26.25
# 3        Bournemouth                 25               12.0  236  19.67
# 4          Brentford                 25               12.0  294   24.5
#
#   SCA Types SCA Types.1 SCA Types.2 SCA Types.3 SCA Types.4 SCA Types.5  GCA  \
# 0  PassLive    PassDead          TO          Sh         Fld         Def  GCA
# 1       220          32          20          25           9           5   43
# 2       234          28          12          28           8           5   46
# 3       173          15          16          14          10           8   15
# 4       200          38          10          24          16           6   29
#
#    GCA.1 GCA Types GCA Types.1 GCA Types.2 GCA Types.3 GCA Types.4  \
# ...

# %%
cols = list(df.iloc[0])
cols[-1] = "Season"
cols
# Out:
# ['Squad',
#  '# Pl',
#  '90s',
#  'SCA',
#  'SCA90',
#  'PassLive',
#  'PassDead',
#  'TO',
#  'Sh',
#  'Fld',
#  'Def',
#  'GCA',
#  'GCA90',
#  'PassLive',
#  'PassDead',
#  'TO',
#  'Sh',
#  'Fld',
#  'Def',
#  'Season']

# %%
df.columns = cols

# %%
df.columns
# Out:
# Index(['Squad', '# Pl', '90s', 'SCA', 'SCA90', 'PassLive', 'PassDead', 'TO',
#        'Sh', 'Fld', 'Def', 'GCA', 'GCA90', 'PassLive', 'PassDead', 'TO', 'Sh',
#        'Fld', 'Def', 'Season'],
#       dtype='object')

# %%
df.head()
# Out:
#          Squad  # Pl   90s  SCA  SCA90  PassLive  PassDead  TO  Sh  Fld  Def  \
# 0        Squad  # Pl   90s  SCA  SCA90  PassLive  PassDead  TO  Sh  Fld  Def
# 1      Arsenal    23  12.0  311  25.92       220        32  20  25    9    5
# 2  Aston Villa    23  12.0  315  26.25       234        28  12  28    8    5
# 3  Bournemouth    25  12.0  236  19.67       173        15  16  14   10    8
# 4    Brentford    25  12.0  294   24.5       200        38  10  24   16    6
#
#    GCA  GCA90  PassLive  PassDead  TO  Sh  Fld  Def     Season
# 0  GCA  GCA90  PassLive  PassDead  TO  Sh  Fld  Def        NaN
# 1   43   3.58        21         6   3   6    7    0  2023-2024
# 2   46   3.83        33         1   4   4    3    1  2023-2024
# 3   15   1.25         9         0   2   2    0    2  2023-2024
# 4   29   2.42        22         1   1   1    4    0  2023-2024

# %%
df.drop(0,inplace=True)

# %%
df
# Out:
#             Squad # Pl   90s   SCA  SCA90 PassLive PassDead  TO  Sh Fld Def  \
# 1         Arsenal   23  12.0   311  25.92      220       32  20  25   9   5
# 2     Aston Villa   23  12.0   315  26.25      234       28  12  28   8   5
# 3     Bournemouth   25  12.0   236  19.67      173       15  16  14  10   8
# 4       Brentford   25  12.0   294   24.5      200       38  10  24  16   6
# 5        Brighton   25  12.0   309  25.75      227       23  23  20  13   3
# ..            ...  ...   ...   ...    ...      ...      ...  ..  ..  ..  ..
# 136  Swansea City   26  38.0   581  15.29      395       57  48  37  33  11
# 137     Tottenham   25  38.0  1092  28.74      811       75  68  72  51  15
# 138       Watford   29  38.0   766  20.16      526       73  60  47  40  20
# 139     West Brom   24  38.0   649  17.08      449       78  40  33  38  11
# 140      West Ham   27  38.0   657  17.29      457       64  57  23  49   7
#
# ...

# %%
df.to_csv("../data-v1/goal_shot_creation.csv", encoding='utf-8')
