# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("../data/passing.csv")

# %%
df.head()
# Out:
#    Unnamed: 0 Unnamed: 0_level_0 Unnamed: 1_level_0 Unnamed: 2_level_0 Total  \
# 0         NaN              Squad               # Pl                90s   Cmp
# 1         0.0            Arsenal                 23               12.0  6268
# 2         1.0        Aston Villa                 23               12.0  5322
# 3         2.0        Bournemouth                 25               12.0  3812
# 4         3.0          Brentford                 25               12.0  4429
#
#   Total.1 Total.2  Total.3  Total.4 Short  ... Unnamed: 17_level_0  \
# 0     Att    Cmp%  TotDist  PrgDist   Cmp  ...                 Ast
# 1    7341    85.4   107054    32954  2892  ...                  14
# 2    6326    84.1    92330    30547  2346  ...                  18
# 3    4987    76.4    68854    24378  1649  ...                   6
# 4    5689    77.9    80283    29549  1916  ...                  13
#
#   Unnamed: 18_level_0 Expected Expected.1 Unnamed: 21_level_0  \
# ...

# %%
df.drop('Unnamed: 0', axis=1, inplace=True)

# %%
df.head()
# Out:
#   Unnamed: 0_level_0 Unnamed: 1_level_0 Unnamed: 2_level_0 Total Total.1  \
# 0              Squad               # Pl                90s   Cmp     Att
# 1            Arsenal                 23               12.0  6268    7341
# 2        Aston Villa                 23               12.0  5322    6326
# 3        Bournemouth                 25               12.0  3812    4987
# 4          Brentford                 25               12.0  4429    5689
#
#   Total.2  Total.3  Total.4 Short Short.1  ... Unnamed: 17_level_0  \
# 0    Cmp%  TotDist  PrgDist   Cmp     Att  ...                 Ast
# 1    85.4   107054    32954  2892    3189  ...                  14
# 2    84.1    92330    30547  2346    2585  ...                  18
# 3    76.4    68854    24378  1649    1880  ...                   6
# 4    77.9    80283    29549  1916    2216  ...                  13
#
#   Unnamed: 18_level_0 Expected Expected.1 Unnamed: 21_level_0  \
# ...

# %%
cols = list(df.iloc[0])
cols[-1] = "Season"
cols
# Out:
# ['Squad',
#  '# Pl',
#  '90s',
#  'Cmp',
#  'Att',
#  'Cmp%',
#  'TotDist',
#  'PrgDist',
#  'Cmp',
#  'Att',
#  'Cmp%',
#  'Cmp',
#  'Att',
#  'Cmp%',
#  'Cmp',
#  'Att',
#  'Cmp%',
#  'Ast',
#  'xAG',
#  'xA',
#  'A-xAG',
#  'KP',
#  '1/3',
#  'PPA',
#  'CrsPA',
#  'PrgP',
#  'Season']

# %%
df.columns = cols

# %%
df.columns
# Out:
# Index(['Squad', '# Pl', '90s', 'Cmp', 'Att', 'Cmp%', 'TotDist', 'PrgDist',
#        'Cmp', 'Att', 'Cmp%', 'Cmp', 'Att', 'Cmp%', 'Cmp', 'Att', 'Cmp%', 'Ast',
#        'xAG', 'xA', 'A-xAG', 'KP', '1/3', 'PPA', 'CrsPA', 'PrgP', 'Season'],
#       dtype='object')

# %%
df.head()
# Out:
#          Squad  # Pl   90s   Cmp   Att  Cmp%  TotDist  PrgDist   Cmp   Att  \
# 0        Squad  # Pl   90s   Cmp   Att  Cmp%  TotDist  PrgDist   Cmp   Att
# 1      Arsenal    23  12.0  6268  7341  85.4   107054    32954  2892  3189
# 2  Aston Villa    23  12.0  5322  6326  84.1    92330    30547  2346  2585
# 3  Bournemouth    25  12.0  3812  4987  76.4    68854    24378  1649  1880
# 4    Brentford    25  12.0  4429  5689  77.9    80283    29549  1916  2216
#
#    ...  Ast   xAG    xA  A-xAG   KP  1/3  PPA  CrsPA  PrgP     Season
# 0  ...  Ast   xAG    xA  A-xAG   KP  1/3  PPA  CrsPA  PrgP        NaN
# 1  ...   14  12.7  13.3    1.3  131  518  145     21   630  2023-2024
# 2  ...   18  16.7  14.9    1.3  140  440  132     28   496  2023-2024
# 3  ...    6   9.3   8.9   -3.3   96  287   95     19   352  2023-2024
# 4  ...   13  16.7  15.2   -3.7  119  299  104     24   456  2023-2024
#
# [5 rows x 27 columns]

# %%
df.drop(0,inplace=True)

# %%
df
# Out:
#             Squad # Pl   90s    Cmp    Att  Cmp% TotDist PrgDist   Cmp   Att  \
# 1         Arsenal   23  12.0   6268   7341  85.4  107054   32954  2892  3189
# 2     Aston Villa   23  12.0   5322   6326  84.1   92330   30547  2346  2585
# 3     Bournemouth   25  12.0   3812   4987  76.4   68854   24378  1649  1880
# 4       Brentford   25  12.0   4429   5689  77.9   80283   29549  1916  2216
# 5        Brighton   25  12.0   6845   7839  87.3  109472   35784  3497  3764
# ..            ...  ...   ...    ...    ...   ...     ...     ...   ...   ...
# 276  Swansea City   26  38.0  13223  17437  75.8  247025   93673  5802  6660
# 277     Tottenham   25  38.0  19284  23695  81.4  363818  126442  7604  8618
# 278       Watford   29  38.0  12758  17513  72.8  225604   93079  6170  7329
# 279     West Brom   24  38.0  10495  15004  69.9  201340   89346  4694  5597
# 280      West Ham   27  38.0  11779  16197  72.7  221883   87777  5113  6041
#
# ...

# %%
df.to_csv("../data-v1/passing.csv", encoding='utf-8')
