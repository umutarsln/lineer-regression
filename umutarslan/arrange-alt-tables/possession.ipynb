# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("../data/possession.csv")

# %%
df.head()
# Out:
#    Unnamed: 0 Unnamed: 0_level_0 Unnamed: 1_level_0 Unnamed: 2_level_0  \
# 0         NaN              Squad               # Pl               Poss
# 1         0.0            Arsenal                 23               60.7
# 2         1.0        Aston Villa                 23               53.8
# 3         2.0        Bournemouth                 25               42.9
# 4         3.0          Brentford                 25               47.7
#
#   Unnamed: 3_level_0  Touches Touches.1 Touches.2 Touches.3 Touches.4  ...  \
# 0                90s  Touches   Def Pen   Def 3rd   Mid 3rd   Att 3rd  ...
# 1               12.0     8485       626      2210      3689      2646  ...
# 2               12.0     7500       798      2400      3409      1761  ...
# 3               12.0     6412       838      2286      2620      1595  ...
# 4               12.0     7038      1008      2791      2708      1599  ...
#
#   Carries.1 Carries.2 Carries.3 Carries.4 Carries.5 Carries.6 Carries.7  \
# ...

# %%
df.drop('Unnamed: 0', axis=1, inplace=True)

# %%
df.head()
# Out:
#   Unnamed: 0_level_0 Unnamed: 1_level_0 Unnamed: 2_level_0 Unnamed: 3_level_0  \
# 0              Squad               # Pl               Poss                90s
# 1            Arsenal                 23               60.7               12.0
# 2        Aston Villa                 23               53.8               12.0
# 3        Bournemouth                 25               42.9               12.0
# 4          Brentford                 25               47.7               12.0
#
#    Touches Touches.1 Touches.2 Touches.3 Touches.4 Touches.5  ... Carries.1  \
# 0  Touches   Def Pen   Def 3rd   Mid 3rd   Att 3rd   Att Pen  ...   TotDist
# 1     8485       626      2210      3689      2646       401  ...     26760
# 2     7500       798      2400      3409      1761       360  ...     26536
# 3     6412       838      2286      2620      1595       276  ...     21385
# 4     7038      1008      2791      2708      1599       354  ...     19332
#
# ...

# %%
cols = list(df.iloc[0])
cols[-1] = "Season"
cols
# Out:
# ['Squad',
#  '# Pl',
#  'Poss',
#  '90s',
#  'Touches',
#  'Def Pen',
#  'Def 3rd',
#  'Mid 3rd',
#  'Att 3rd',
#  'Att Pen',
#  'Live',
#  'Att',
#  'Succ',
#  'Succ%',
#  'Tkld',
#  'Tkld%',
#  'Carries',
#  'TotDist',
#  'PrgDist',
#  'PrgC',
#  '1/3',
#  'CPA',
#  'Mis',
#  'Dis',
#  'Rec',
#  'PrgR',
#  'Season']

# %%
df.columns = cols

# %%
df.columns
# Out:
# Index(['Squad', '# Pl', 'Poss', '90s', 'Touches', 'Def Pen', 'Def 3rd',
#        'Mid 3rd', 'Att 3rd', 'Att Pen', 'Live', 'Att', 'Succ', 'Succ%', 'Tkld',
#        'Tkld%', 'Carries', 'TotDist', 'PrgDist', 'PrgC', '1/3', 'CPA', 'Mis',
#        'Dis', 'Rec', 'PrgR', 'Season'],
#       dtype='object')

# %%
df.head()
# Out:
#          Squad  # Pl  Poss   90s  Touches  Def Pen  Def 3rd  Mid 3rd  Att 3rd  \
# 0        Squad  # Pl  Poss   90s  Touches  Def Pen  Def 3rd  Mid 3rd  Att 3rd
# 1      Arsenal    23  60.7  12.0     8485      626     2210     3689     2646
# 2  Aston Villa    23  53.8  12.0     7500      798     2400     3409     1761
# 3  Bournemouth    25  42.9  12.0     6412      838     2286     2620     1595
# 4    Brentford    25  47.7  12.0     7038     1008     2791     2708     1599
#
#    Att Pen  ...  TotDist  PrgDist  PrgC  1/3  CPA  Mis  Dis   Rec  PrgR  \
# 0  Att Pen  ...  TotDist  PrgDist  PrgC  1/3  CPA  Mis  Dis   Rec  PrgR
# 1      401  ...    26760    13711   245  160   83  136  123  6197   620
# 2      360  ...    26536    14295   254  156   74  154  104  5214   493
# 3      276  ...    21385    11042   197  152   53  188  125  3770   348
# 4      354  ...    19332    10303   172  110   59  165   83  4382   457
#
#       Season
# 0        NaN
# 1  2023-2024
# 2  2023-2024
# ...

# %%
df.drop(0,inplace=True)

# %%
df
# Out:
#             Squad # Pl  Poss   90s Touches Def Pen Def 3rd Mid 3rd Att 3rd  \
# 1         Arsenal   23  60.7  12.0    8485     626    2210    3689    2646
# 2     Aston Villa   23  53.8  12.0    7500     798    2400    3409    1761
# 3     Bournemouth   25  42.9  12.0    6412     838    2286    2620    1595
# 4       Brentford   25  47.7  12.0    7038    1008    2791    2708    1599
# 5        Brighton   25  61.4  12.0    9102     963    2972    4222    1973
# ..            ...  ...   ...   ...     ...     ...     ...     ...     ...
# 136  Swansea City   26  45.3  38.0   21278    2441    7047    9908    4554
# 137     Tottenham   25  61.8  38.0   27821    2080    7157   13466    7466
# 138       Watford   29  49.7  38.0   21692    2087    6318   10225    5377
# 139     West Brom   24  40.7  38.0   19184    2302    6698    8221    4468
# 140      West Ham   27  45.2  38.0   20454    2265    6198    9854    4647
#
# ...

# %%
df.to_csv("../data-v1/possession.csv", encoding='utf-8')
