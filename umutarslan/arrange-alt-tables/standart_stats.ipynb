# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("../data/standart_stats.csv")

# %%
df.head()
# Out:
#    Unnamed: 0 Expected Expected.1 Expected.2 Expected.3 Per 90 Minutes  \
# 0         NaN     npxG   npxG+xAG        xAG         xG            Ast
# 1         0.0     16.5       29.3       12.7       21.0           1.17
# 2         1.0     21.2       37.9       16.7       23.5            1.5
# 3         2.0     13.8       23.1        9.3       13.8            0.5
# 4         3.0     20.8       37.5       16.7       22.1           1.08
#
#   Per 90 Minutes.1 Per 90 Minutes.2 Per 90 Minutes.3 Per 90 Minutes.4  ...  \
# 0              G+A           G+A-PK             G-PK              Gls  ...
# 1             3.25             2.75             1.58             2.08  ...
# 2             3.67             3.42             1.92             2.17  ...
# 3             1.42             1.42             0.92             0.92  ...
# 4             2.58             2.42             1.33              1.5  ...
#
#   Playing Time.1 Playing Time.2 Playing Time.3 Progression Progression.1  \
# ...

# %%
df.drop('Unnamed: 0', axis=1, inplace=True)

# %%
df.head()
# Out:
#   Expected Expected.1 Expected.2 Expected.3 Per 90 Minutes Per 90 Minutes.1  \
# 0     npxG   npxG+xAG        xAG         xG            Ast              G+A
# 1     16.5       29.3       12.7       21.0           1.17             3.25
# 2     21.2       37.9       16.7       23.5            1.5             3.67
# 3     13.8       23.1        9.3       13.8            0.5             1.42
# 4     20.8       37.5       16.7       22.1           1.08             2.58
#
#   Per 90 Minutes.2 Per 90 Minutes.3 Per 90 Minutes.4 Per 90 Minutes.5  ...  \
# 0           G+A-PK             G-PK              Gls             npxG  ...
# 1             2.75             1.58             2.08             1.38  ...
# 2             3.42             1.92             2.17             1.77  ...
# 3             1.42             0.92             0.92             1.15  ...
# 4             2.42             1.33              1.5             1.73  ...
#
# ...

# %%
cols = list(df.iloc[0])
cols[-1] = "Season"
cols
# Out:
# ['npxG',
#  'npxG+xAG',
#  'xAG',
#  'xG',
#  'Ast',
#  'G+A',
#  'G+A-PK',
#  'G-PK',
#  'Gls',
#  'npxG',
#  'npxG+xAG',
#  'xAG',
#  'xG',
#  'xG+xAG',
#  'Ast',
#  'CrdR',
#  'CrdY',
#  'G+A',
#  'G-PK',
#  'Gls',
#  'PK',
#  'PKatt',
#  '90s',
#  'MP',
#  'Min',
#  'Starts',
#  'PrgC',
#  'PrgP',
#  'Squad',
#  '# Pl',
#  'Age',
#  'Poss',
#  'Season']

# %%
df.columns = cols

# %%
ordered_cols = ['Squad','npxG',
 'npxG+xAG',
 'xAG',
 'xG',
 'Ast',
 'G+A',
 'G+A-PK',
 'G-PK',
 'Gls',
 'npxG',
 'npxG+xAG',
 'xAG',
 'xG',
 'xG+xAG',
 'Ast',
 'CrdR',
 'CrdY',
 'G+A',
 'G-PK',
 'Gls',
 'PK',
 'PKatt',
 '90s',
 'MP',
 'Min',
 'Starts',
 'PrgC',
 'PrgP',
 '# Pl',
 'Age',
 'Poss',
 'Season']

# %%
df = df[ordered_cols]

# %%
df.columns
# Out:
# Index(['Squad', 'npxG', 'npxG', 'npxG+xAG', 'npxG+xAG', 'xAG', 'xAG', 'xG',
#        'xG', 'Ast', 'Ast', 'G+A', 'G+A', 'G+A-PK', 'G-PK', 'G-PK', 'Gls',
#        'Gls', 'npxG', 'npxG', 'npxG+xAG', 'npxG+xAG', 'xAG', 'xAG', 'xG', 'xG',
#        'xG+xAG', 'Ast', 'Ast', 'CrdR', 'CrdY', 'G+A', 'G+A', 'G-PK', 'G-PK',
#        'Gls', 'Gls', 'PK', 'PKatt', '90s', 'MP', 'Min', 'Starts', 'PrgC',
#        'PrgP', '# Pl', 'Age', 'Poss', 'Season'],
#       dtype='object')

# %%
df.head()
# Out:
#          Squad  npxG  npxG  npxG+xAG  npxG+xAG   xAG   xAG    xG    xG   Ast  \
# 0        Squad  npxG  npxG  npxG+xAG  npxG+xAG   xAG   xAG    xG    xG   Ast
# 1      Arsenal  16.5  1.38      29.3      2.44  12.7  1.06  21.0  1.75  1.17
# 2  Aston Villa  21.2  1.77      37.9      3.16  16.7  1.39  23.5  1.96   1.5
# 3  Bournemouth  13.8  1.15      23.1      1.93   9.3  0.77  13.8  1.15   0.5
# 4    Brentford  20.8  1.73      37.5      3.12  16.7  1.39  22.1  1.84  1.08
#
#    ...   90s  MP   Min  Starts   PrgC   PrgP  # Pl   Age  Poss     Season
# 0  ...   90s  MP   Min  Starts   PrgC   PrgP  # Pl   Age  Poss        NaN
# 1  ...  12.0  12  1080     132  245.0  630.0    23  25.2  60.7  2023-2024
# 2  ...  12.0  12  1080     132  254.0  496.0    23  27.1  53.8  2023-2024
# 3  ...  12.0  12  1080     132  197.0  352.0    25  25.7  42.9  2023-2024
# 4  ...  12.0  12  1080     132  172.0  456.0    25  26.6  47.7  2023-2024
#
# [5 rows x 49 columns]

# %%
df.drop(0,inplace=True)

# %%
df
# Out:
#               Squad  npxG  npxG npxG+xAG npxG+xAG   xAG   xAG    xG    xG  \
# 1           Arsenal  16.5  1.38     29.3     2.44  12.7  1.06  21.0  1.75
# 2       Aston Villa  21.2  1.77     37.9     3.16  16.7  1.39  23.5  1.96
# 3       Bournemouth  13.8  1.15     23.1     1.93   9.3  0.77  13.8  1.15
# 4         Brentford  20.8  1.73     37.5     3.12  16.7  1.39  22.1  1.84
# 5          Brighton  20.0  1.67     36.5     3.04  16.5  1.38  20.8  1.73
# ..              ...   ...   ...      ...      ...   ...   ...   ...   ...
# 642   Sheffield Utd   NaN   NaN      NaN      NaN   NaN   NaN   NaN   NaN
# 643  Sheffield Weds   NaN   NaN      NaN      NaN   NaN   NaN   NaN   NaN
# 644     Southampton   NaN   NaN      NaN      NaN   NaN   NaN   NaN   NaN
# 645       Tottenham   NaN   NaN      NaN      NaN   NaN   NaN   NaN   NaN
# 646       Wimbledon   NaN   NaN      NaN      NaN   NaN   NaN   NaN   NaN
#
#       Ast  ...   90s  MP   Min Starts   PrgC   PrgP # Pl   Age  Poss  \
# ...

# %%
df_no_duplicates = df.T.drop_duplicates().T

# %%
df_no_duplicates
# Out:
#               Squad  npxG  npxG npxG+xAG npxG+xAG   xAG   xAG    xG    xG  \
# 1           Arsenal  16.5  1.38     29.3     2.44  12.7  1.06  21.0  1.75
# 2       Aston Villa  21.2  1.77     37.9     3.16  16.7  1.39  23.5  1.96
# 3       Bournemouth  13.8  1.15     23.1     1.93   9.3  0.77  13.8  1.15
# 4         Brentford  20.8  1.73     37.5     3.12  16.7  1.39  22.1  1.84
# 5          Brighton  20.0  1.67     36.5     3.04  16.5  1.38  20.8  1.73
# ..              ...   ...   ...      ...      ...   ...   ...   ...   ...
# 642   Sheffield Utd   NaN   NaN      NaN      NaN   NaN   NaN   NaN   NaN
# 643  Sheffield Weds   NaN   NaN      NaN      NaN   NaN   NaN   NaN   NaN
# 644     Southampton   NaN   NaN      NaN      NaN   NaN   NaN   NaN   NaN
# 645       Tottenham   NaN   NaN      NaN      NaN   NaN   NaN   NaN   NaN
# 646       Wimbledon   NaN   NaN      NaN      NaN   NaN   NaN   NaN   NaN
#
#       Ast  ...   90s  MP   Min Starts   PrgC   PrgP # Pl   Age  Poss  \
# ...

# %%
df_no_duplicates.to_csv("../data-v1/standart_stats.csv", encoding='utf-8')
