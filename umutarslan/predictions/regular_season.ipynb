# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %%
df = pd.read_csv("../data-v2/regular_season.csv")

# %%
df.head()
# Out:
#    Unnamed: 0  Rk            Squad  MP  W  D  L  GF  GA  GD  Pts  Pts/MP  \
# 0           0   1  Manchester City  12  9  1  2  32  12  20   28    2.33
# 1           1   2        Liverpool  12  8  3  1  27  10  17   27    2.25
# 2           2   3          Arsenal  12  8  3  1  26  10  16   27    2.25
# 3           3   4        Tottenham  12  8  2  2  24  15   9   26    2.17
# 4           4   5      Aston Villa  12  8  1  3  29  17  12   25    2.08
#
#       season
# 0  2023-2024
# 1  2023-2024
# 2  2023-2024
# 3  2023-2024
# 4  2023-2024

# %%
df.drop(columns="Unnamed: 0", axis=1, inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 688 entries, 0 to 687
# Data columns (total 12 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Rk      688 non-null    int64
#  1   Squad   688 non-null    object
#  2   MP      688 non-null    int64
#  3   W       688 non-null    int64
#  4   D       688 non-null    int64
#  5   L       688 non-null    int64
#  6   GF      688 non-null    int64
#  7   GA      688 non-null    int64
#  8   GD      688 non-null    int64
#  9   Pts     688 non-null    int64
#  10  Pts/MP  688 non-null    float64
#  11  season  688 non-null    object
# dtypes: float64(1), int64(9), object(2)
# memory usage: 64.6+ KB

# %%
sns.pairplot(df)

# %%
import statsmodels.api as sm
import statsmodels.formula.api as smf
import patsy
from sklearn.linear_model import LinearRegression
